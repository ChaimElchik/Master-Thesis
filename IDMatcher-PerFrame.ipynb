# %%
from copy import deepcopy
from pathlib import Path
import cv2
import matplotlib.pylab as plt
import numpy as np
from scipy.io import loadmat
from scipy.ndimage import gaussian_filter
from tqdm import tqdm
import cv2
import pandas as pd
import numpy as np 
import cv2 
from matplotlib import pyplot as plt 
import math
import os
import cv2
from scipy.io import loadmat
from copy import deepcopy

# %%
# Read the bounding box coordinates from the CSV file
csv_path_1 = '129_1_clean.txt'
df1_left_view = pd.read_csv(csv_path_1)

# Read the bounding box coordinates from the CSV file
csv_path_2 = '129_2_clean.txt'
df2_right_view = pd.read_csv(csv_path_2)

# %%
display(df1_left_view)
display(df2_right_view)
# Out:
#        frame  id        x       y  x_offset  y_offset
# 0          1   1  1212.98  416.74     26.04     14.37
# 1          1   2  1151.14  415.00     27.58     10.34
# 2          1   3  1487.32  431.94     17.38     19.86
# 3          1   4  1080.11  337.38     18.68      6.46
# 4          1   5  1220.90  325.30     21.28     10.54
# ...      ...  ..      ...     ...       ...       ...
# 30196   3117   5  1011.60  235.99     10.38     22.01
# 30197   3117   6  1304.99  217.40     15.01     24.80
# 30198   3117   7   969.60  489.40     23.90     16.40
# 30199   3117   8  1037.36  245.93     14.89     29.79
# 30200   3117   9  1103.97  670.34     22.04     25.01
#
# [30201 rows x 6 columns]
#        frame  id        x       y  x_offset  y_offset
# 0          1   1  1010.39  357.55     21.50      7.74
# 1          1   2  1151.46  337.71     20.11     17.63
# 2          1   3  1173.87  341.47     11.20     12.02
# 3          1   4  1446.30  460.60     19.11     20.90
# 4          1   5  1066.87  626.29     48.07      6.87
# ...      ...  ..      ...     ...       ...       ...
# 30644   3118   5   949.07  696.08     23.25     33.30
# 30645   3118   6  1067.44  288.15     38.96     21.85
# 30646   3118   7  1188.06  193.33     33.94     17.14
# 30647   3118   8   883.91  514.11     25.29     14.69
# 30648   3118   9   934.50  265.34     14.50     25.66
#
# [30649 rows x 6 columns]

# %%
import cv2

# Read the video file
video_path = '../vids/129_1.mp4'
cap = cv2.VideoCapture(video_path)

def save_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Initialize frame count
    frame_count = 0

    # Read the first frame
    success, frame = video_capture.read()

    # Loop through the video frames
    while success:
        # Save the frame as a JPEG image
        output_path = f"{output_folder}/129_1_frame_{frame_count}.jpg"
        cv2.imwrite(output_path, frame)

        # Read the next frame
        success, frame = video_capture.read()

        # Increment frame count
        frame_count += 1

    # Release the video capture object
    video_capture.release()

# Example usage:
output_folder = "Frames_129_1"
save_frames(video_path, output_folder)

# %%
import cv2

# Read the video file
video_path = '../vids/129_2.mp4'
cap = cv2.VideoCapture(video_path)

def save_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Initialize frame count
    frame_count = -1

    # Read the first frame
    success, frame = video_capture.read()

    # Loop through the video frames
    while success:
        # Save the frame as a JPEG image
        output_path = f"{output_folder}/129_2_frame_{frame_count}.jpg"
        cv2.imwrite(output_path, frame)

        # Read the next frame
        success, frame = video_capture.read()

        # Increment frame count
        frame_count += 1

    # Release the video capture object
    video_capture.release()

# Example usage:
output_folder = "Frames_129_2"
save_frames(video_path, output_folder)

# %%
CameraDataFile = "stereoParams_Dep4.mat"

# %%
def Undistorter_1(folder_path, camera_data_file):
    # Load camera data
    dd = loadmat(camera_data_file)
    distCoeffs1 = deepcopy(dd["distortionCoefficients1"])
    distCoeffs2 = deepcopy(dd["distortionCoefficients2"])
    cameraMatrix1 = deepcopy(dd["intrinsicMatrix1"])
    cameraMatrix2 = deepcopy(dd["intrinsicMatrix2"])
    R = deepcopy(dd["rotationOfCamera2"])
    T = deepcopy(dd["translationOfCamera2"])
    cameraMatrix1[0:2, 2] += 1
    cameraMatrix2[0:2, 2] += 1
    
#     # Create output folder for undistorted frames
    output_folder = "Frames_129_1_undistorted"
    os.makedirs(output_folder, exist_ok=True)
    
    # Loop through images in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            # Read image
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            
            # Undistort image
            img_undistorted = cv2.undistort(img, cameraMatrix1, distCoeffs1)
            
            # Save undistorted image
            undistorted_filename = os.path.splitext(filename)[0] + '_undistorted.jpg'
            output_path = os.path.join(output_folder, undistorted_filename)
            cv2.imwrite(output_path, img_undistorted)

# Example usage:
# folder_path = "Frames_129_1"
camera_data_file = "stereoParams_Dep4.mat"
Undistorter_1("Frames_129_1", camera_data_file)

# %%
def Undistorter_2(folder_path, camera_data_file):
    # Load camera data
    dd = loadmat(camera_data_file)
    distCoeffs1 = deepcopy(dd["distortionCoefficients1"])
    distCoeffs2 = deepcopy(dd["distortionCoefficients2"])
    cameraMatrix1 = deepcopy(dd["intrinsicMatrix1"])
    cameraMatrix2 = deepcopy(dd["intrinsicMatrix2"])
    R = deepcopy(dd["rotationOfCamera2"])
    T = deepcopy(dd["translationOfCamera2"])
    cameraMatrix1[0:2, 2] += 1
    cameraMatrix2[0:2, 2] += 1
    
    output_folder = "Frames_129_2_undistorted"
    os.makedirs(output_folder, exist_ok=True)
    
    # Loop through images in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            # Read image
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            
            # Undistort image
            img_undistorted = cv2.undistort(img, cameraMatrix1, distCoeffs1)
            
            # Save undistorted image
            undistorted_filename = os.path.splitext(filename)[0] + '_undistorted.jpg'
            output_path = os.path.join(output_folder, undistorted_filename)
            cv2.imwrite(output_path, img_undistorted)

# Example usage:
# folder_path = "Frames_129_2"
camera_data_file = "stereoParams_Dep4.mat"
Undistorter_2("Frames_129_2", camera_data_file)

# %%
# # Define the folder path
# folder_path = 'Frames_129_1_undistorted'

# # List all files in the folder
# file_names = os.listdir(folder_path)



# # print(int(file_names[1].split('_frame_')[1].split('_undistorted.jpg')[0]))
# # print(file_names[1])
# for x in file_names:
#     if '_frame_' not in x:
#         print(x)

# %%
# # Define the folder path
# folder_path_1 = 'Frames_129_1_undistorted'

# # List all files in the folder
# file_names_1 = os.listdir(folder_path_1)

# # Extract the frame numbers from the file names
# frame_numbers_1 = [int(file_name.split('_frame_')[1].split('_undistorted.jpg')[0]) for file_name in file_names_1 if file_name != '.DS_Store']

# # Sort the file names based on the frame numbers
# sorted_files_129_1 = [file_name for _, file_name in sorted(zip(frame_numbers_1, file_names_1))]

# # Display the sorted file names
# print((sorted_files_129_1))

# # print(frame_numbers)

import os

# Define the folder path
folder_path_1 = 'Frames_129_1_undistorted'

# List all files in the folder
file_names_1 = os.listdir(folder_path_1)

# Extract the frame numbers from the file names and sort
sorted_files_129_1 = sorted([file_name for file_name in file_names_1 if file_name != '.DS_Store'],
                            key=lambda x: int(x.split('_frame_')[1].split('_undistorted.jpg')[0]))

# Display the sorted file names
print(sorted_files_129_1)
# Out:
# ['129_1_frame_0_undistorted.jpg', '129_1_frame_1_undistorted.jpg', '129_1_frame_2_undistorted.jpg', '129_1_frame_3_undistorted.jpg', '129_1_frame_4_undistorted.jpg', '129_1_frame_5_undistorted.jpg', '129_1_frame_6_undistorted.jpg', '129_1_frame_7_undistorted.jpg', '129_1_frame_8_undistorted.jpg', '129_1_frame_9_undistorted.jpg', '129_1_frame_10_undistorted.jpg', '129_1_frame_11_undistorted.jpg', '129_1_frame_12_undistorted.jpg', '129_1_frame_13_undistorted.jpg', '129_1_frame_14_undistorted.jpg', '129_1_frame_15_undistorted.jpg', '129_1_frame_16_undistorted.jpg', '129_1_frame_17_undistorted.jpg', '129_1_frame_18_undistorted.jpg', '129_1_frame_19_undistorted.jpg', '129_1_frame_20_undistorted.jpg', '129_1_frame_21_undistorted.jpg', '129_1_frame_22_undistorted.jpg', '129_1_frame_23_undistorted.jpg', '129_1_frame_24_undistorted.jpg', '129_1_frame_25_undistorted.jpg', '129_1_frame_26_undistorted.jpg', '129_1_frame_27_undistorted.jpg', '129_1_frame_28_undistorted.jpg', '129_1_frame_29_undistorted.jpg', '129_1_frame_30_undistorted.jpg', '129_1_frame_31_undistorted.jpg', '129_1_frame_32_undistorted.jpg', '129_1_frame_33_undistorted.jpg', '129_1_frame_34_undistorted.jpg', '129_1_frame_35_undistorted.jpg', '129_1_frame_36_undistorted.jpg', '129_1_frame_37_undistorted.jpg', '129_1_frame_38_undistorted.jpg', '129_1_frame_39_undistorted.jpg', '129_1_frame_40_undistorted.jpg', '129_1_frame_41_undistorted.jpg', '129_1_frame_42_undistorted.jpg', '129_1_frame_43_undistorted.jpg', '129_1_frame_44_undistorted.jpg', '129_1_frame_45_undistorted.jpg', '129_1_frame_46_undistorted.jpg', '129_1_frame_47_undistorted.jpg', '129_1_frame_48_undistorted.jpg', '129_1_frame_49_undistorted.jpg', '129_1_frame_50_undistorted.jpg', '129_1_frame_51_undistorted.jpg', '129_1_frame_52_undistorted.jpg', '129_1_frame_53_undistorted.jpg', '129_1_frame_54_undistorted.jpg', '129_1_frame_55_undistorted.jpg', '129_1_frame_56_undistorted.jpg', '129_1_frame_57_undistorted.jpg', '129_1_frame_58_undistorted.jpg', '129_1_frame_59_undistorted.jpg', '129_1_frame_60_undistorted.jpg', '129_1_frame_61_undistorted.jpg', '129_1_frame_62_undistorted.jpg', '129_1_frame_63_undistorted.jpg', '129_1_frame_64_undistorted.jpg', '129_1_frame_65_undistorted.jpg', '129_1_frame_66_undistorted.jpg', '129_1_frame_67_undistorted.jpg', '129_1_frame_68_undistorted.jpg', '129_1_frame_69_undistorted.jpg', '129_1_frame_70_undistorted.jpg', '129_1_frame_71_undistorted.jpg', '129_1_frame_72_undistorted.jpg', '129_1_frame_73_undistorted.jpg', '129_1_frame_74_undistorted.jpg', '129_1_frame_75_undistorted.jpg', '129_1_frame_76_undistorted.jpg', '129_1_frame_77_undistorted.jpg', '129_1_frame_78_undistorted.jpg', '129_1_frame_79_undistorted.jpg', '129_1_frame_80_undistorted.jpg', '129_1_frame_81_undistorted.jpg', '129_1_frame_82_undistorted.jpg', '129_1_frame_83_undistorted.jpg', '129_1_frame_84_undistorted.jpg', '129_1_frame_85_undistorted.jpg', '129_1_frame_86_undistorted.jpg', '129_1_frame_87_undistorted.jpg', '129_1_frame_88_undistorted.jpg', '129_1_frame_89_undistorted.jpg', '129_1_frame_90_undistorted.jpg', '129_1_frame_91_undistorted.jpg', '129_1_frame_92_undistorted.jpg', '129_1_frame_93_undistorted.jpg', '129_1_frame_94_undistorted.jpg', '129_1_frame_95_undistorted.jpg', '129_1_frame_96_undistorted.jpg', '129_1_frame_97_undistorted.jpg', '129_1_frame_98_undistorted.jpg', '129_1_frame_99_undistorted.jpg', '129_1_frame_100_undistorted.jpg', '129_1_frame_101_undistorted.jpg', '129_1_frame_102_undistorted.jpg', '129_1_frame_103_undistorted.jpg', '129_1_frame_104_undistorted.jpg', '129_1_frame_105_undistorted.jpg', '129_1_frame_106_undistorted.jpg', '129_1_frame_107_undistorted.jpg', '129_1_frame_108_undistorted.jpg', '129_1_frame_109_undistorted.jpg', '129_1_frame_110_undistorted.jpg', '129_1_frame_111_undistorted.jpg', '129_1_frame_112_undistorted.jpg', '129_1_frame_113_undistorted.jpg', '129_1_frame_114_undistorted.jpg', '129_1_frame_115_undistorted.jpg', '129_1_frame_116_undistorted.jpg', '129_1_frame_1 ...

# %%
# Define the folder path
folder_path_2 = 'Frames_129_2_undistorted'

# List all files in the folder
file_names_2 = os.listdir(folder_path_2)

# Extract the frame numbers from the file names
frame_numbers_2 = [int(file_name.split('_frame_')[1].split('_undistorted.jpg')[0]) for file_name in file_names_2]

# Sort the file names based on the frame numbers
sorted_files_129_2 = [file_name for _, file_name in sorted(zip(frame_numbers_2, file_names_2))]

# Display the sorted file names
print(sorted_files_129_2)

# print(frame_numbers)
# print(file_names)
# Out:
# ['129_2_frame_-1_undistorted.jpg', '129_2_frame_0_undistorted.jpg', '129_2_frame_1_undistorted.jpg', '129_2_frame_2_undistorted.jpg', '129_2_frame_3_undistorted.jpg', '129_2_frame_4_undistorted.jpg', '129_2_frame_5_undistorted.jpg', '129_2_frame_6_undistorted.jpg', '129_2_frame_7_undistorted.jpg', '129_2_frame_8_undistorted.jpg', '129_2_frame_9_undistorted.jpg', '129_2_frame_10_undistorted.jpg', '129_2_frame_11_undistorted.jpg', '129_2_frame_12_undistorted.jpg', '129_2_frame_13_undistorted.jpg', '129_2_frame_14_undistorted.jpg', '129_2_frame_15_undistorted.jpg', '129_2_frame_16_undistorted.jpg', '129_2_frame_17_undistorted.jpg', '129_2_frame_18_undistorted.jpg', '129_2_frame_19_undistorted.jpg', '129_2_frame_20_undistorted.jpg', '129_2_frame_21_undistorted.jpg', '129_2_frame_22_undistorted.jpg', '129_2_frame_23_undistorted.jpg', '129_2_frame_24_undistorted.jpg', '129_2_frame_25_undistorted.jpg', '129_2_frame_26_undistorted.jpg', '129_2_frame_27_undistorted.jpg', '129_2_frame_28_undistorted.jpg', '129_2_frame_29_undistorted.jpg', '129_2_frame_30_undistorted.jpg', '129_2_frame_31_undistorted.jpg', '129_2_frame_32_undistorted.jpg', '129_2_frame_33_undistorted.jpg', '129_2_frame_34_undistorted.jpg', '129_2_frame_35_undistorted.jpg', '129_2_frame_36_undistorted.jpg', '129_2_frame_37_undistorted.jpg', '129_2_frame_38_undistorted.jpg', '129_2_frame_39_undistorted.jpg', '129_2_frame_40_undistorted.jpg', '129_2_frame_41_undistorted.jpg', '129_2_frame_42_undistorted.jpg', '129_2_frame_43_undistorted.jpg', '129_2_frame_44_undistorted.jpg', '129_2_frame_45_undistorted.jpg', '129_2_frame_46_undistorted.jpg', '129_2_frame_47_undistorted.jpg', '129_2_frame_48_undistorted.jpg', '129_2_frame_49_undistorted.jpg', '129_2_frame_50_undistorted.jpg', '129_2_frame_51_undistorted.jpg', '129_2_frame_52_undistorted.jpg', '129_2_frame_53_undistorted.jpg', '129_2_frame_54_undistorted.jpg', '129_2_frame_55_undistorted.jpg', '129_2_frame_56_undistorted.jpg', '129_2_frame_57_undistorted.jpg', '129_2_frame_58_undistorted.jpg', '129_2_frame_59_undistorted.jpg', '129_2_frame_60_undistorted.jpg', '129_2_frame_61_undistorted.jpg', '129_2_frame_62_undistorted.jpg', '129_2_frame_63_undistorted.jpg', '129_2_frame_64_undistorted.jpg', '129_2_frame_65_undistorted.jpg', '129_2_frame_66_undistorted.jpg', '129_2_frame_67_undistorted.jpg', '129_2_frame_68_undistorted.jpg', '129_2_frame_69_undistorted.jpg', '129_2_frame_70_undistorted.jpg', '129_2_frame_71_undistorted.jpg', '129_2_frame_72_undistorted.jpg', '129_2_frame_73_undistorted.jpg', '129_2_frame_74_undistorted.jpg', '129_2_frame_75_undistorted.jpg', '129_2_frame_76_undistorted.jpg', '129_2_frame_77_undistorted.jpg', '129_2_frame_78_undistorted.jpg', '129_2_frame_79_undistorted.jpg', '129_2_frame_80_undistorted.jpg', '129_2_frame_81_undistorted.jpg', '129_2_frame_82_undistorted.jpg', '129_2_frame_83_undistorted.jpg', '129_2_frame_84_undistorted.jpg', '129_2_frame_85_undistorted.jpg', '129_2_frame_86_undistorted.jpg', '129_2_frame_87_undistorted.jpg', '129_2_frame_88_undistorted.jpg', '129_2_frame_89_undistorted.jpg', '129_2_frame_90_undistorted.jpg', '129_2_frame_91_undistorted.jpg', '129_2_frame_92_undistorted.jpg', '129_2_frame_93_undistorted.jpg', '129_2_frame_94_undistorted.jpg', '129_2_frame_95_undistorted.jpg', '129_2_frame_96_undistorted.jpg', '129_2_frame_97_undistorted.jpg', '129_2_frame_98_undistorted.jpg', '129_2_frame_99_undistorted.jpg', '129_2_frame_100_undistorted.jpg', '129_2_frame_101_undistorted.jpg', '129_2_frame_102_undistorted.jpg', '129_2_frame_103_undistorted.jpg', '129_2_frame_104_undistorted.jpg', '129_2_frame_105_undistorted.jpg', '129_2_frame_106_undistorted.jpg', '129_2_frame_107_undistorted.jpg', '129_2_frame_108_undistorted.jpg', '129_2_frame_109_undistorted.jpg', '129_2_frame_110_undistorted.jpg', '129_2_frame_111_undistorted.jpg', '129_2_frame_112_undistorted.jpg', '129_2_frame_113_undistorted.jpg', '129_2_frame_114_undistorted.jpg', '129_2_frame_115_undistorted.jpg', '129_2_frame_11 ...

# %%
import re

image_left_keypoints_dict = dict()
image_right_keypoints_dict = dict()
fundamental_matrix_dict = dict()

for index in range(len(sorted_files_129_1)):
    # Target value
    target_value = sorted_files_129_1[index]

    # Extract frame number from the target value
    target_frame_number = int(re.search(r'_frame_(\d+)_undistorted.jpg', target_value).group(1))
    
    img_2 = [x for x in sorted_files_129_2 if ('frame_' + str(target_frame_number) + '_') in x][0]
    
    img_1 = sorted_files_129_1[index]
    
    print(type(img_2))
    print(img_2)
    print(type(img_1))
    print(img_1)
    
    dd = loadmat(CameraDataFile)
    distCoeffs1 = deepcopy(dd["distortionCoefficients1"])
    distCoeffs2 = deepcopy(dd["distortionCoefficients2"])
    cameraMatrix1 = deepcopy(dd["intrinsicMatrix1"])
    cameraMatrix2 = deepcopy(dd["intrinsicMatrix2"])
    R = deepcopy(dd["rotationOfCamera2"])
    T = deepcopy(dd["translationOfCamera2"])
    cameraMatrix1[0:2, 2] += 1
    cameraMatrix2[0:2, 2] += 1
    # Projection matrices
    P1 = np.dot(cameraMatrix1, np.hstack((np.eye(3), np.zeros((3, 1)))))
    P2 = np.dot(cameraMatrix2, np.hstack((R, T.reshape(3, 1))))
    
    filepath1 = 'Frames_129_1_undistorted/'+img_1
    filepath2 = 'Frames_129_2_undistorted/'+img_2
    
    print(filepath1)
    print(filepath2)
    
    # Load the undistorted stereo images
    img_left = cv2.imread(filepath1, cv2.IMREAD_GRAYSCALE)
    img_right = cv2.imread(filepath2, cv2.IMREAD_GRAYSCALE)

    # Initialize SIFT detector
    sift = cv2.SIFT_create()

    # Detect keypoints and compute descriptors
    keypoints_left, descriptors_left = sift.detectAndCompute(img_left, None)
    keypoints_right, descriptors_right = sift.detectAndCompute(img_right, None)

    # Undistort keypoints
    keypoints_left_undistorted = cv2.undistortPoints(np.array([kp.pt for kp in keypoints_left]).reshape(-1, 1, 2), cameraMatrix1, distCoeffs1, P=cameraMatrix1)
    keypoints_right_undistorted = cv2.undistortPoints(np.array([kp.pt for kp in keypoints_right]).reshape(-1, 1, 2), cameraMatrix2, distCoeffs2, P=cameraMatrix2)

    # Convert keypoints back to OpenCV KeyPoint format
    keypoints_left_undistorted = [cv2.KeyPoint(x[0][0], x[0][1], 1) for x in keypoints_left_undistorted]
    keypoints_right_undistorted = [cv2.KeyPoint(x[0][0], x[0][1], 1) for x in keypoints_right_undistorted]

    # Create FLANN matcher object
    FLANN_INDEX_KDTREE = 0
    index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
    search_params = dict(checks=50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)

    # Match descriptors of left and right images
    matches = flann.knnMatch(descriptors_left, descriptors_right, k=2)

    # Apply ratio test
    good_matches = []
    pts_left = []
    pts_right = []

    for m, n in matches:
        if m.distance < 0.8 * n.distance:
            good_matches.append(m)
            pts_left.append(keypoints_left_undistorted[m.queryIdx].pt)
            pts_right.append(keypoints_right_undistorted[m.trainIdx].pt)

    pts_left = np.int32(pts_left) 
    pts_right = np.int32(pts_right) 
    F, mask = cv2.findFundamentalMat(pts_left, 
                                     pts_right, 
                                     cv2.FM_LMEDS) 

    # We select only inlier points 
    pts_left = pts_left[mask.ravel() == 1] 
    pts_right = pts_right[mask.ravel() == 1] 
    
    image_left_keypoints_dict[index] = keypoints_left_undistorted
    image_right_keypoints_dict[index] = keypoints_right_undistorted
    fundamental_matrix_dict[index] = F

# %%
print(len(image_left_keypoints_dict))
print(len(image_right_keypoints_dict))
print(len(fundamental_matrix_dict))

# %%
def find_matching_points(left_point, fundamental_matrix, right_image_keypoints):
    
    # Convert left point to homogeneous coordinates
    left_point = np.array([left_point[0], left_point[1], 1])

    # Compute the epipolar line in the right image corresponding to the left point
    epipolar_line = np.dot(fundamental_matrix, left_point)
    # Calculate the bounds for the search area in the right image
    search_area_width = 200  # You can adjust this based on your requirement
    search_area_height = 200  # You can adjust this based on your requirement

    # Define the search area
    search_area = ((left_point[0] - search_area_width, left_point[1] - search_area_height),
                   (left_point[0] + search_area_width, left_point[1] + search_area_height))

    # Initialize a list to store potential matching points
    potential_matching_points = []

    # Iterate through all keypoints in the right image
    for keypoint in right_image_keypoints:
        x, y = keypoint.pt

        # Check if the keypoint lies within the search area
        if search_area[0][0] <= x <= search_area[1][0] and search_area[0][1] <= y <= search_area[1][1]:
            # Compute the distance between the keypoint and the epipolar line
            distance = abs(epipolar_line[0] * x + epipolar_line[1] * y + epipolar_line[2]) / \
                       np.sqrt(epipolar_line[0] ** 2 + epipolar_line[1] ** 2)

            # You can adjust this threshold based on your requirement
            if distance < 30:  # Adjust this threshold as needed
                potential_matching_points.append((x, y))

    return potential_matching_points

# %%
def closest_tuple(given_tuple, tuple_list):
    
    closest = None
    min_distance = float('inf')
    
    for tpl in tuple_list:
        distance = math.sqrt(sum((x - y) ** 2 for x, y in zip(given_tuple, tpl)))
        if distance < min_distance:
            min_distance = distance
            closest = tpl
    
    return closest

# %%
def tuple_differences(tuple1, tuple2):
    if len(tuple1) != len(tuple2):
        raise ValueError("Tuples must have the same length")
    
    return tuple(x - y for x, y in zip(tuple1, tuple2))

# %%
def Find_Matching_ID(left_id, left_point_tuple, right_view_dataframe, fundamental_matrix, right_image_keypoints):
    
    matching_points = find_matching_points(left_point_tuple, fundamental_matrix, right_image_keypoints)
    
    options = []
    
    df = pd.DataFrame(columns=['left_id','right_id','difference','frame'])
    difference = None
    for index, row in right_view_dataframe.iterrows():
        tuple_right = (row['x'],row['y'])
        
        difference = abs(tuple_differences(tuple_right,closest_tuple(tuple_right, matching_points))[0]) + abs(tuple_differences(tuple_right,closest_tuple(tuple_right, matching_points))[1])
        new_row_data = {'left_id': left_id, 'right_id': row['id'],'difference': difference,'frame':row['frame']}
        new_row = pd.DataFrame(new_row_data,index=[0])
        df = pd.concat([df, new_row], ignore_index=True)

        
    return df

# %%
frames_to_check = [x for x in range(298)]  # Example list of frames to check
print(frames_to_check)
# Filter df2_right_view for frames in frames_to_check
df1_test = df1_left_view[df1_left_view['frame'].isin(frames_to_check)]

df2_test = df2_right_view[df2_right_view['frame'].isin(frames_to_check)]

display(df1_test)
display(df2_test)

# %%
df_preds = pd.DataFrame()
frames = set(df1_test['frame'])
for frame in frames:
    df_to_use = df1_test[df1_test['frame'] == frame]
    df_to_check = df2_test[df2_test['frame'] == frame]
#     display(df_to_use)

    for index, row in df_to_use.iterrows():
        frame = row['frame']
        id_value = row['id']
        x = row['x']
        y = row['y']
        left_id = id_value
        left_point_tuple = (x,y)
#         print(left_id,left_point_tuple,frame)
        df_mathces = Find_Matching_ID(left_id, left_point_tuple, df_to_check, fundamental_matrix_dict[frame], image_right_keypoints_dict[frame])
        min_difference_index = df_mathces['difference'].idxmin()

        # Retrieve the corresponding row from the DataFrame
        row_with_smallest_difference = df_mathces.loc[min_difference_index]

        # Convert the row to a DataFrame
        row_df = row_with_smallest_difference.to_frame().T

        df_preds = pd.concat([df_preds,row_df],ignore_index=True)

# %%
df_preds

# %%
# Subtract 1 from each value in 'left_id' and 'right_id'
df_preds['right_id'] = df_preds['right_id'].apply(lambda x: x - 1)
df_preds['left_id'] = df_preds['left_id'].apply(lambda x: x - 1)
df_preds

# %%
# Save the DataFrame as a CSV file
df_preds.to_csv('df_preds_V4.csv', index=False)

# %%
gt_matches = {3:0, 5:1, 4:2, 2:3, 8:4, 0:5, 1:6, 6:7, 7:8, 9:9, 10:10, 11:11, 12:12, 13:13, 14:14}
# based on amount of matches per frame
match_count_dict = dict()
for frame in set(df_preds['frame']):
    match_count = 0
    temp = df_preds.loc[df_preds['frame'] == frame]
#     print(list(temp['left_id']),list(temp['right_id']))
    left_l = list(temp['left_id'])
    right_l = list(temp['right_id'])
    for x in range(len(left_l)):
#         print(left_l[x],right_l[x])
        if gt_matches[left_l[x]] == right_l[x]:
#             print("MATCH",left_l[x],right_l[x],frame)
            match_count += 1
    match_count_dict[frame] = match_count/len(left_l)
# match_count_dict

average_value_matches = sum(match_count_dict.values()) / len(match_count_dict)
print(average_value_matches)
# print(match_count_dict)
